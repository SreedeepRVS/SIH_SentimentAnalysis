# %%
import pandas as pd

# %%
df = pd.read_csv('MusicalInstruments.csv')

# %%
del_cols = df.drop(['unixReviewTime','reviewTime','asin','reviewerName'],axis=1)

# %%
del_cols.to_csv('ChangedInstruments.csv',index=False)

# %%
del_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10261 entries, 0 to 10260
# Data columns (total 6 columns):
# reviewerID    10261 non-null object
# helpful/0     10261 non-null int64
# helpful/1     10261 non-null int64
# reviewText    10254 non-null object
# overall       10261 non-null int64
# summary       10261 non-null object
# dtypes: int64(3), object(3)
# memory usage: 481.1+ KB

# %%
df = del_cols

# %%
df['reviewText']
# Out:
# 0        Not much to write about here, but it does exac...
# 1        The product does exactly as it should and is q...
# 2        The primary job of this device is to block the...
# 3        Nice windscreen protects my MXL mic and preven...
# 4        This pop filter is great. It looks and perform...
# 5        So good that I bought another one.  Love the h...
# 6        I have used monster cables for years, and with...
# 7        I now use this cable to run from the output of...
# 8        Perfect for my Epiphone Sheraton II.  Monster ...
# 9        Monster makes the best cables and a lifetime w...
# 10       Monster makes a wide array of cables, includin...
# 11       I got it to have it if I needed it. I have fou...
# 12       If you are not use to using a large sustaining...
# 13       I love it, I used this for my Yamaha ypt-230 a...
# 14       I bought this to use in my home studio to cont...
# 15       I bought this to use with my keyboard. I wasn'...
# ...

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10254 entries, 0 to 10260
# Data columns (total 6 columns):
# reviewerID    10254 non-null object
# helpful/0     10254 non-null int64
# helpful/1     10254 non-null int64
# reviewText    10254 non-null object
# overall       10254 non-null int64
# summary       10254 non-null object
# dtypes: int64(3), object(3)
# memory usage: 560.8+ KB

# %%
df.to_csv('ChangedInstruments.csv',index=False)

# %%
df = df[df.summary!='-']

# %%
df.to_csv('ChangedInstruments.csv')

# %%
df
# Out:
#            reviewerID  helpful/0  helpful/1  \
# 0      A2IBPI20UZIR0U          0          0
# 1      A14VAT5EAX3D9S         13         14
# 2      A195EZSQDW3E21          1          1
# 3      A2C00NNG1ZQQG2          0          0
# 4       A94QU4C90B1AX          0          0
# 5      A2A039TZMZHH9Y          0          0
# 6      A1UPZM995ZAH90          0          0
# 7       AJNFQI3YR6XJ5          0          0
# 8      A3M1PLEYNDEYO8          0          0
# 9       AMNTZU1YQN1TH          0          0
# 10     A2NYK9KWFMJV4Y          6          6
# 11     A35QFQI0M46LWO          0          0
# 12     A2NIT6BKW11XJQ          0          0
# 13     A1C0O09LOLVI39          0          0
# 14     A17SLR18TUMULM          0          0
# 15     A2PD27UKAD3Q00          0          0
# 16      AKSFZ4G1AXYFC          0          0
# 17      A67OJZLHBBUQ9          0          0
# 18     A2EZWZ8MBEDOLN          3          3
# 19     A1CL807EOUPVP1          0          0
# ...

# %%
df['reviewText'] = df['reviewText'].str.lower()
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#            reviewerID  helpful/0  helpful/1  \
# 0      A2IBPI20UZIR0U          0          0
# 1      A14VAT5EAX3D9S         13         14
# 2      A195EZSQDW3E21          1          1
# 3      A2C00NNG1ZQQG2          0          0
# 4       A94QU4C90B1AX          0          0
# 5      A2A039TZMZHH9Y          0          0
# 6      A1UPZM995ZAH90          0          0
# 7       AJNFQI3YR6XJ5          0          0
# 8      A3M1PLEYNDEYO8          0          0
# 9       AMNTZU1YQN1TH          0          0
# 10     A2NYK9KWFMJV4Y          6          6
# 11     A35QFQI0M46LWO          0          0
# 12     A2NIT6BKW11XJQ          0          0
# 13     A1C0O09LOLVI39          0          0
# 14     A17SLR18TUMULM          0          0
# 15     A2PD27UKAD3Q00          0          0
# 16      AKSFZ4G1AXYFC          0          0
# 17      A67OJZLHBBUQ9          0          0
# 18     A2EZWZ8MBEDOLN          3          3
# 19     A1CL807EOUPVP1          0          0
# ...

# %%
def remove_punctuation(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    return s

df['reviewText'] = df['reviewText'].apply(remove_punctuation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-7efaba7ef74d> in <module>
#       3     return s
#       4
# ----> 5 df['reviewText'] = df['reviewText'].apply(remove_punctuation)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-55-7efaba7ef74d> in remove_punctuation(s)
#       1 def remove_punctuation(s):
# ----> 2     s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
#       3     return s
#       4
# ...

# %%
import string
def remove_punctuation(s):
    s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
    return s

df['reviewText'] = df['reviewText'].apply(remove_punctuation)
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#            reviewerID  helpful/0  helpful/1  \
# 0      A2IBPI20UZIR0U          0          0
# 1      A14VAT5EAX3D9S         13         14
# 2      A195EZSQDW3E21          1          1
# 3      A2C00NNG1ZQQG2          0          0
# 4       A94QU4C90B1AX          0          0
# 5      A2A039TZMZHH9Y          0          0
# 6      A1UPZM995ZAH90          0          0
# 7       AJNFQI3YR6XJ5          0          0
# 8      A3M1PLEYNDEYO8          0          0
# 9       AMNTZU1YQN1TH          0          0
# 10     A2NYK9KWFMJV4Y          6          6
# 11     A35QFQI0M46LWO          0          0
# 12     A2NIT6BKW11XJQ          0          0
# 13     A1C0O09LOLVI39          0          0
# 14     A17SLR18TUMULM          0          0
# 15     A2PD27UKAD3Q00          0          0
# 16      AKSFZ4G1AXYFC          0          0
# 17      A67OJZLHBBUQ9          0          0
# 18     A2EZWZ8MBEDOLN          3          3
# 19     A1CL807EOUPVP1          0          0
# ...

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('english')
df['withoutSW'] = df['reviewText'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anmol\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
df['tokenized_sents'] = df.apply(lambda row: nltk.word_tokenize(row['withoutSW']), axis=1)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Anmol\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.to_csv('new.csv',index=False)

# %%
df
# Out:
#            reviewerID  helpful/0  helpful/1  \
# 0      A2IBPI20UZIR0U          0          0
# 1      A14VAT5EAX3D9S         13         14
# 2      A195EZSQDW3E21          1          1
# 3      A2C00NNG1ZQQG2          0          0
# 4       A94QU4C90B1AX          0          0
# 5      A2A039TZMZHH9Y          0          0
# 6      A1UPZM995ZAH90          0          0
# 7       AJNFQI3YR6XJ5          0          0
# 8      A3M1PLEYNDEYO8          0          0
# 9       AMNTZU1YQN1TH          0          0
# 10     A2NYK9KWFMJV4Y          6          6
# 11     A35QFQI0M46LWO          0          0
# 12     A2NIT6BKW11XJQ          0          0
# 13     A1C0O09LOLVI39          0          0
# 14     A17SLR18TUMULM          0          0
# 15     A2PD27UKAD3Q00          0          0
# 16      AKSFZ4G1AXYFC          0          0
# 17      A67OJZLHBBUQ9          0          0
# 18     A2EZWZ8MBEDOLN          3          3
# 19     A1CL807EOUPVP1          0          0
# ...

# %%
import gensim 
from gensim.models import Word2Vec 
model = Word2Vec(df['tokenized_sents'], min_count=1)
#df['new_column'] = model[df['tokenized_sents']]

# %%
print(model["i"])
# Out:
# C:\Users\Anmol\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-48a64d11a748> in <module>
# ----> 1 print(model["i"])
#
# ~\Anaconda3\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __getitem__(self, words)
#    1119
#    1120         """
# -> 1121         return self.wv.__getitem__(words)
#    1122
# ...

# %%
pip install --upgrade gensim
# Out:
# ...
#   Stored in directory: C:\Users\Anmol\AppData\Local\pip\Cache\wheels\ab\10\93\5cff86f5b721d77edaecc29959b1c60d894be1f66d91407d28
# Successfully built smart-open
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask-wtf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask_wtf import FlaskForm
from wtforms import StringField, PasswordField, BooleanField, SubmitField
from wtforms.validators import DataRequired

class LoginForm(FlaskForm):
    username = StringField('Username', validators=[DataRequired()])
    password = PasswordField('Password', validators=[DataRequired()])
    remember_me = BooleanField('Remember Me')
    submit = SubmitField('Sign In')

# %%
pip install virtualenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, redirect, url_for, request 
app = Flask(__name__) 
  
@app.route('/success/<name>') 
def success(name): 
   return 'welcome %s' % name 
  
@app.route('/login',methods = ['POST', 'GET']) 
def login(): 
   if request.method == 'POST': 
      user = request.form['nm'] 
      return redirect(url_for('success',name = user)) 
   else: 
      user = request.args.get('nm') 
      return redirect(url_for('success',name = user)) 
  
if __name__ == '__main__': 
   app.run(debug = True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\Anmol\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
